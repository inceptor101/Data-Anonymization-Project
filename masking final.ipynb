# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset = pd.read_csv("C:/Users/rutvi/DF.csv")

# %%
dataset.shape
dataset.head(10)
# Out:
#   Customer_ID      Month             Name  Age          SSN Occupation  \
# 0   CUS_0xd40  September    Aaron Maashoh   23  821-00-0265  Scientist
# 1   CUS_0xd40    October    Aaron Maashoh   24  821-00-0265  Scientist
# 2   CUS_0xd40   November    Aaron Maashoh   24  821-00-0265  Scientist
# 3   CUS_0xd40   December    Aaron Maashoh   24  821-00-0265  Scientist
# 4  CUS_0x21b1  September  Rick Rothackerj   28  004-07-5839    _______
# 5  CUS_0x21b1    October  Rick Rothackerj   28    #F%$D@*&8    Teacher
# 6  CUS_0x21b1   November  Rick Rothackerj   28  004-07-5839    Teacher
# 7  CUS_0x21b1   December  Rick Rothackerj   28  004-07-5839    Teacher
# 8  CUS_0x2dbc  September           Langep   35  486-85-3974   Engineer
# 9  CUS_0x2dbc    October           Langep   35  486-85-3974   Engineer
#
#    Annual_Income  Num_Bank_Accounts                        Mail  Num_of_Loan  \
# 0       19114.12                  3     atomkiewicz@hotmail.com            4
# ...

# %%
from anonympy.pandas import dfAnonymizer
from anonympy.pandas.utils_pandas import available_methods
from anonympy.pandas.utils_pandas import fake_methods

# %%
anonym = dfAnonymizer(dataset)
available_methods()
# Out:
# `numeric`:
#         * Perturbation - "numeric_noise"
#         * Binning - "numeric_binning"
#         * PCA Masking - "numeric_masking"
#         * Rounding - "numeric_rounding"
#
# `categorical`:
#         * Synthetic Data - "categorical_fake"
#         * Synthetic Data Auto - "categorical_fake_auto"
#         * Resampling from same Distribution - "categorical_resampling"
#         * Tokenazation - "categorical_tokenization"
#         * Email Masking - "categorical_email_masking"
#
# `datetime`:
#         * Synthetic Date - "datetime_fake"
#         * Perturbation - "datetime_noise"
#
# `general`:
#         * Drop Column - "column_suppression"

# %%
anonym.numeric_rounding('Annual_Income')
anonym.numeric_rounding('Num_of_Loan')
anonym.categorical_tokenization('SSN')
anonym.categorical_email_masking('Mail')
anonym.numeric_masking('Age')
anonym.column_suppression('Credit_History_Age')
anonym.numeric_noise("Monthly_Balance")

# %%
anonym.categorical_email_masking('Mail')
# Out:
# `Mail` column already anonymized!

# %%
anonym.info()
# Out:
# +-------------------------+--------+-------------+---------------------------+
# |         Column          | Status |    Type     |          Method           |
# +=========================+========+=============+===========================+
# | Customer_ID             | 0      | categorical |                           |
# +-------------------------+--------+-------------+---------------------------+
# | Month                   | 0      | categorical |                           |
# +-------------------------+--------+-------------+---------------------------+
# | Name                    | 0      | categorical |                           |
# +-------------------------+--------+-------------+---------------------------+
# | Age                     | 1      | numeric     | PCA Masking               |
# +-------------------------+--------+-------------+---------------------------+
# | SSN                     | 1      | categorical | Tokenization              |
# ...

# %%
anonym.anonymize({'Age': 'numeric_masking',  # {'column_name': 'method_name'}
                  'SSN': 'categorical_tokenization',
                  'Annual_Income': 'numeric_rounding',
                  'Num_of_Loan': 'numeric_rounding',
                  'Credit_History_Age': 'column_suppression', 
                  'Monthly_Balance':'numeric_noise',
                  'Mail' : 'categorical_email_masking'})
print(anonym.to_df()) # Final result after anonymization.
# Out:
# `Age` column already anonymized!
# `SSN` column already anonymized!
# `Annual_Income` column already anonymized!
# `Num_of_Loan` column already anonymized!
# `Credit_History_Age` column already anonymized!
# `Monthly_Balance` column already anonymized!
# `Mail` column already anonymized!
#    Customer_ID      Month             Name          Age         SSN  \
# 0    CUS_0xd40  September    Aaron Maashoh   -78.833333  e8e2b26d45
# 1    CUS_0xd40    October    Aaron Maashoh   -77.833333  e8e2b26d45
# 2    CUS_0xd40   November    Aaron Maashoh   -77.833333  e8e2b26d45
# 3    CUS_0xd40   December    Aaron Maashoh   -77.833333  e8e2b26d45
# 4   CUS_0x21b1  September  Rick Rothackerj   -73.833333  43df258268
# 5   CUS_0x21b1    October  Rick Rothackerj   -73.833333  ef380173bf
# 6   CUS_0x21b1   November  Rick Rothackerj   -73.833333  43df258268
# 7   CUS_0x21b1   December  Rick Rothackerj   -73.833333  43df258268
# 8   CUS_0x2dbc  September           Langep   -66.833333  4fd078bfcb
# ...
